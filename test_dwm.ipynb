# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import seaborn
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# *//Reading Data for Bihar for MAY*
#
# ---

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/test_data.csv")
avg_rain= df.loc[df['SUBDIVISION']=='Bihar']
avg_rain= avg_rain[['YEAR','MAY']]
avg_rain= avg_rain.set_index(['YEAR'])
avg_rain.head(5)
# Out:
#         MAY
# YEAR
# 1901   65.6
# 1902   66.3
# 1903   28.2
# 1904  118.7
# 1905   77.5

# %%
plt.plot(avg_rain)

# %%
#rolling stats for stationarity
rol1= avg_rain.rolling(window=12).mean()
rol2= avg_rain.rolling(window=12).std()
print (rol1,rol2)
# Out:
#             MAY
# YEAR
# 1901        NaN
# 1902        NaN
# 1903        NaN
# 1904        NaN
# 1905        NaN
# 1906        NaN
# 1907        NaN
# 1908        NaN
# 1909        NaN
# 1910        NaN
# 1911        NaN
# 1912  54.358333
# 1913  57.733333
# 1914  58.625000
# 1915  62.316667
# 1916  54.516667
# 1917  56.666667
# 1918  61.725000
# 1919  62.508333
# 1920  61.850000
# 1921  61.891667
# 1922  59.433333
# 1923  59.133333
# 1924  55.141667
# 1925  49.516667
# 1926  47.016667
# 1927  45.383333
# 1928  47.816667
# 1929  41.966667
# 1930  35.566667
# ...         ...
# 1988  61.366667
# 1989  62.750000
# 1990  65.375000
# 1991  67.458333
# 1992  65.808333
# 1993  62.875000
# 1994  63.016667
# 1995  56.816667
# 1996  52.866667
# 1997  50.616667
# 1998  45.941667
# 1999  49.566667
# 2000  53.733333
# 2001  53.575000
# 2002  52.866667
# 2003  53.716667
# 2004  54.683333
# 2005  52.808333
# 2006  56.183333
# 2007  63.491667
# 2008  66.050000
# 2009  70.741667
# 2010  71.258333
# 2011  70.500000
# 2012  64.050000
# 2013  63.308333
# 2014  65.733333
# 2015  65.575000
# 2016  66.516667
# 2017  70.775000
#
# [117 rows x 1 columns]             MAY
# YEAR
# 1901        NaN
# 1902        NaN
# 1903        NaN
# 1904        NaN
# 1905        NaN
# 1906        NaN
# 1907        NaN
# 1908        NaN
# 1909        NaN
# 1910        NaN
# 1911        NaN
# 1912  26.194637
# 1913  30.093622
# 1914  30.525939
# 1915  29.160148
# 1916  24.916910
# 1917  28.002413
# 1918  30.969461
# 1919  30.285414
# 1920  30.975430
# 1921  30.922821
# 1922  32.931426
# 1923  33.123497
# 1924  35.458489
# 1925  31.805569
# 1926  30.605312
# 1927  29.629127
# 1928  29.004352
# 1929  23.318519
# 1930  12.227564
# ...         ...
# 1988  26.619553
# 1989  28.266057
# 1990  28.617195
# 1991  24.536706
# 1992  24.214250
# 1993  23.631263
# 1994  23.427018
# 1995  27.667435
# 1996  29.614534
# 1997  29.284617
# 1998  25.967023
# 1999  28.031616
# 2000  31.040277
# 2001  30.784947
# 2002  30.129639
# 2003  29.602083
# 2004  30.051103
# 2005  30.982501
# 2006  30.798254
# 2007  28.292031
# 2008  25.023389
# 2009  25.419944
# 2010  24.752648
# 2011  24.478042
# 2012  27.142871
# 2013  26.225021
# 2014  28.620283
# 2015  28.771992
# 2016  29.207995
# 2017  26.803498
#
# [117 rows x 1 columns]

# %%
#plotting mean and std deviation
orig= plt.plot(avg_rain,color="red",label="original")
avg= plt.plot(rol1,color="green",label="mean")
std= plt.plot(rol2,color="blue",label="std")
plt.title("rolling mean and standard deviation")
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
print("DF test")
dftest= adfuller(avg_rain['MAY'],autolag="AIC")
dfop= pd.Series(dftest[0:4],index=["test stats","p-value","lags used","no of observations used"])
for key,value in dftest[4].items():
  dfop["Critical value used (%s)"%key]= value


print (dfop)

#proves that data is non stationary
# Out:
# DF test
# test stats                  -9.219772e+00
# p-value                      1.793015e-15
# lags used                    0.000000e+00
# no of observations used      1.160000e+02
# Critical value used (1%)    -3.488022e+00
# Critical value used (5%)    -2.886797e+00
# Critical value used (10%)   -2.580241e+00
# dtype: float64

# %%
avg_rainlog= np.log(avg_rain)
plt.plot(avg_rainlog)

# %%
mrol1= avg_rainlog.rolling(window=12).mean()
mrol2= avg_rainlog.rolling(window=12).std()
#plotting mean and std deviation for moving average
orig= plt.plot(avg_rainlog,color="red",label="original")
avg= plt.plot(mrol1,color="green",label="mean")
std= plt.plot(mrol2,color="blue",label="std")
plt.title("moving mean and standard deviation")
plt.show(block=False)

# %%
normalized_avg_rain= avg_rainlog - mrol1
normalized_avg_rain.dropna(inplace=True)
normalized_avg_rain.head()
# Out:
#            MAY
# YEAR
# 1912  0.238278
# 1913  0.724231
# 1914  0.391186
# 1915  0.252279
# 1916 -0.678962

# %%
from statsmodels.tsa.stattools import adfuller
def calculate(test):
 mrol1= test.rolling(window=12).mean()
 mrol2= test.rolling(window=12).std()
#plotting mean and std deviation for moving average
 orig= plt.plot(test,color="red",label="original")
 avg= plt.plot(mrol1,color="green",label="mean")
 std= plt.plot(mrol2,color="blue",label="std")
 plt.title("moving mean and standard deviation")
 plt.show(block=False)
 print("DF test")
 dftest= adfuller(test['MAY'],autolag="AIC")
 dfop= pd.Series(dftest[0:4],index=["test stats","p-value","lags used","no of observations used"])
 for key,value in dftest[4].items():
   dfop["Critical value used (%s)"%key]= value
 print (dfop)

# %%
calculate(normalized_avg_rain)
# Out:
# DF test
# test stats                  -9.599620e+00
# p-value                      1.936299e-16
# lags used                    0.000000e+00
# no of observations used      1.050000e+02
# Critical value used (1%)    -3.494220e+00
# Critical value used (5%)    -2.889485e+00
# Critical value used (10%)   -2.581676e+00
# dtype: float64

# %%
edecay= avg_rainlog.ewm(halflife=12,min_periods=0,adjust=True).mean()
plt.plot(avg_rainlog)
plt.plot(edecay,color="red")

# %%
avg_rain_decay= avg_rainlog - edecay
calculate (avg_rain_decay)
# Out:
# DF test
# test stats                  -1.021080e+01
# p-value                      5.645208e-18
# lags used                    0.000000e+00
# no of observations used      1.160000e+02
# Critical value used (1%)    -3.488022e+00
# Critical value used (5%)    -2.886797e+00
# Critical value used (10%)   -2.580241e+00
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompfreq = 6*12
avg_rainlog.reset_index(inplace=True)
avg_rainlog['YEAR'] = pd.to_datetime(avg_rainlog['YEAR'])
avg_rainlog = avg_rainlog.set_index('YEAR')
decompose= seasonal_decompose(avg_rainlog,freq=decompfreq)
trend= decompose.trend()
seasonality= decompose.seasonal()
residual= decompose.resid()
plt.subplot(411)
plt.show(avg_rainlog,label='original')
plt.subplot(412)
plt.show(trend,label='trend')
plt.subplot(413)
plt.show(seasonal,label='seasonal')
plt.subplot(414)
plt.show(residual,label='residual')

decomposed_logdata= residual
decomposed_logdata.dropna(inplace=True)
calculate(decomposed_logdata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0d5faf2854a4> in <module>()
#       5 avg_rainlog = avg_rainlog.set_index('YEAR')
#       6 decompose= seasonal_decompose(avg_rainlog,freq=decompfreq)
# ----> 7 trend= decompose.trend()
#       8 seasonality= decompose.seasonal()
#       9 residual= decompose.resid()
#
# TypeError: 'DataFrame' object is not callable

# %%
ds_logdiff_shift= normalized_avg_rain - normalized_avg_rain.shift()
plt.plot(ds_logdiff_shift)

# %%
ds_logdiff_shift.dropna(inplace=True)
calculate(ds_logdiff_shift)
# Out:
# DF test
# test stats                  -7.379801e+00
# p-value                      8.531676e-11
# lags used                    5.000000e+00
# no of observations used      9.900000e+01
# Critical value used (1%)    -3.498198e+00
# Critical value used (5%)    -2.891208e+00
# Critical value used (10%)   -2.582596e+00
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf , pacf

lag_acf= acf(ds_logdiff_shift,nlags=20)
lag_pacf= pacf(ds_logdiff_shift,nlags=20,method="ols")

#ACF plot
plt.subplot(211)
plt.plot(lag_acf)
plt.axhline (y=0,linestyle="--",color="gray")
plt.axhline (y=-1.96/np.sqrt(len(ds_logdiff_shift)),linestyle="--",color="gray")
plt.axhline (y=1.96/np.sqrt(len(ds_logdiff_shift)),linestyle="--",color="gray")
plt.title("ACF")


plt.subplot(212)
plt.plot(lag_pacf)
plt.axhline (y=0,linestyle="--",color="gray")
plt.axhline (y=-1.96/np.sqrt(len(ds_logdiff_shift)),linestyle="--",color="gray")
plt.axhline (y=1.96/np.sqrt(len(ds_logdiff_shift)),linestyle="--",color="gray")
plt.title("PACF")
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

model= ARIMA(normalized_avg_rain, order=(1,1,0))
results_AR= model.fit(disp=-1)
plt.plot(ds_logdiff_shift)
plt.plot(results_AR.fittedvalues,color="red")
plt.title('RSS: %4f'%sum((results_AR.fittedvalues-ds_logdiff_shift['MAY'])*2))
print("Plotting AR Model")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Plotting AR Model

# %%
predictions_diff= pd.Series(results_AR.fittedvalues,copy=True)
print(predictions_diff.head())
# Out:
# YEAR
# 1913   -0.001312
# 1914   -0.232048
# 1915    0.155773
# 1916    0.063843
# 1917    0.439038
# dtype: float64

# %%
predictions_diff_cum= predictions_diff.cumsum()
print(predictions_diff_cum.head())
# Out:
# YEAR
# 1913   -0.001312
# 1914   -0.233361
# 1915   -0.077588
# 1916   -0.013745
# 1917    0.425294
# dtype: float64

# %%
prediction_ARIMA_Log= pd.Series(normalized_avg_rain['MAY'],index= normalized_avg_rain.index)
prediction_ARIMA_Log= prediction_ARIMA_Log.add(predictions_diff_cum,fill_value=0)
print(prediction_ARIMA_Log.head())
# Out:
# YEAR
# 1912    0.238278
# 1913    0.722918
# 1914    0.157826
# 1915    0.174691
# 1916   -0.692707
# dtype: float64

# %%
predict= np.exp(prediction_ARIMA_Log)
plt.plot(normalized_avg_rain)
plt.plot(predict)

# %%
normalized_avg_rain
# Out:
#            MAY
# YEAR
# 1912  0.238278
# 1913  0.724231
# 1914  0.391186
# 1915  0.252279
# 1916 -0.678962
# 1917  0.711861
# 1918  0.660503
# 1919 -0.273415
# 1920 -0.637627
# 1921 -0.730033
# 1922 -0.837681
# 1923 -0.280985
# 1924 -1.106261
# 1925 -0.063375
# 1926  0.174658
# 1927  0.319179
# 1928  0.280996
# 1929 -0.119153
# 1930 -0.156584
# 1931 -0.159921
# 1932 -0.186574
# 1933  0.932855
# 1934 -0.479240
# 1935 -0.437652
# 1936  0.765264
# 1937  0.652178
# 1938  0.944495
# 1939 -0.058857
# 1940 -0.277618
# 1941  0.407073
# ...        ...
# 1988 -0.114629
# 1989  0.645480
# 1990  0.420174
# 1991 -0.696512
# 1992 -0.001026
# 1993 -0.136083
# 1994 -0.586942
# 1995 -1.964411
# 1996 -0.858251
# 1997  0.023963
# 1998 -0.000318
# 1999  0.721668
# 2000  0.800933
# 2001  0.825138
# 2002  0.559884
# 2003 -0.055225
# 2004  0.493350
# 2005 -0.391220
# 2006  0.481417
# 2007  0.515310
# 2008 -0.224817
# 2009  0.404826
# 2010 -0.404525
# 2011  0.122639
# 2012 -1.118256
# 2013  0.450026
# 2014  0.571832
# 2015 -0.391381
# 2016  0.351095
# 2017  0.213143
#
# [106 rows x 1 columns]

# %%
results_AR.plot_predict(80,110)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
results_AR.forecast(steps=120)
# Out:
# (array([0.27653374, 0.24458216, 0.25777825, 0.24959549, 0.25153629,
#         0.24868326, 0.24810026, 0.24644233, 0.24529342, 0.24390347,
#         0.24262766, 0.2412978 , 0.23999353, 0.23867715, 0.2373665 ,
#         0.23605314, 0.23474106, 0.23342837, 0.23211597, 0.23080344,
#         0.22949097, 0.22817847, 0.22686598, 0.22555349, 0.224241  ,
#         0.22292851, 0.22161602, 0.22030353, 0.21899104, 0.21767855,
#         0.21636606, 0.21505356, 0.21374107, 0.21242858, 0.21111609,
#         0.2098036 , 0.20849111, 0.20717862, 0.20586613, 0.20455364,
#         0.20324115, 0.20192866, 0.20061617, 0.19930367, 0.19799118,
#         0.19667869, 0.1953662 , 0.19405371, 0.19274122, 0.19142873,
#         0.19011624, 0.18880375, 0.18749126, 0.18617877, 0.18486628,
#         0.18355379, 0.18224129, 0.1809288 , 0.17961631, 0.17830382,
#         0.17699133, 0.17567884, 0.17436635, 0.17305386, 0.17174137,
#         0.17042888, 0.16911639, 0.1678039 , 0.16649141, 0.16517891,
#         0.16386642, 0.16255393, 0.16124144, 0.15992895, 0.15861646,
#         0.15730397, 0.15599148, 0.15467899, 0.1533665 , 0.15205401,
#         0.15074152, 0.14942902, 0.14811653, 0.14680404, 0.14549155,
#         0.14417906, 0.14286657, 0.14155408, 0.14024159, 0.1389291 ,
#         0.13761661, 0.13630412, 0.13499163, 0.13367914, 0.13236664,
#         0.13105415, 0.12974166, 0.12842917, 0.12711668, 0.12580419,
#         0.1244917 , 0.12317921, 0.12186672, 0.12055423, 0.11924174,
#         0.11792925, 0.11661676, 0.11530426, 0.11399177, 0.11267928,
#         0.11136679, 0.1100543 , 0.10874181, 0.10742932, 0.10611683,
#         0.10480434, 0.10349185, 0.10217936, 0.10086687, 0.09955437]),
#  array([0.84549005, 0.95550434, 1.14710294, 1.26996028, 1.39924697,
#         1.50988051, 1.61632079, 1.71466012, 1.80833543, 1.89708535,
#         1.98200367, 2.06336711, 2.14167048, 2.21719702, 2.29024027,
#         2.36102208, 2.42974406, 2.4965745 , 2.56166228, 2.62513664,
#         2.68711211, 2.74769001, 2.80696088, 2.86500582, 2.92189789,
#         2.97770319, 3.0324817 , 3.08628809, 3.13917237, 3.19118037,
#         3.24235425, 3.29273292, 3.34235232, 3.39124579, 3.43944428,
#         3.48697662, 3.53386968, 3.58014858, 3.62583685, 3.67095652,
#         3.71552833, 3.75957175, 3.80310514, 3.84614582, 3.88871015,
#         3.9308136 , 3.97247084, 4.01369574, 4.05450151, 4.09490067,
#         4.13490513, 4.17452625, 4.21377484, 4.25266121, 4.29119521,
#         4.32938625, 4.36724332, 4.40477504, 4.44198966, 4.47889508,
#         4.51549888, 4.55180833, 4.58783043, 4.62357189, 4.65903917,
#         4.69423848, 4.72917582, 4.76385693, 4.79828738, 4.83247253,
#         4.86641755, 4.90012742, 4.93360697, 4.96686085, 4.99989356,
#         5.03270947, 5.06531278, 5.09770758, 5.1298978 , 5.1618873 ,
#         5.19367976, 5.22527879, 5.25668787, 5.28791039, 5.31894964,
#         5.34980881, 5.38049098, 5.41099919, 5.44133634, 5.47150529,
#         5.5015088 , 5.53134957, 5.56103021, 5.59055328, 5.61992126,
#         5.64913656, 5.67820155, 5.70711852, 5.73588971, 5.76451731,
#         5.79300343, 5.82135016, 5.84955953, 5.87763351, 5.90557403,
#         5.93338298, 5.9610622 , 5.98861349, 6.0160386 , 6.04333926,
#         6.07051715, 6.09757389, 6.12451111, 6.15133037, 6.1780332 ,
#         6.20462112, 6.23109559, 6.25745804, 6.2837099 , 6.30985254]),
#  array([[ -1.38059631,   1.93366379],
#         [ -1.62817193,   2.11733626],
#         [ -1.9905022 ,   2.5060587 ],
#         [ -2.23948092,   2.73867189],
#         [ -2.49093738,   2.99400995],
#         [ -2.71062817,   3.20799469],
#         [ -2.91983027,   3.41603079],
#         [ -3.11422974,   3.60711441],
#         [ -3.29897889,   3.78956573],
#         [ -3.47431549,   3.96212243],
#         [ -3.64202816,   4.12728348],
#         [ -3.80282743,   4.28542302],
#         [ -3.95760347,   4.43759054],
#         [ -4.10694916,   4.58430346],
#         [ -4.25142194,   4.72615494],
#         [ -4.3914651 ,   4.86357137],
#         [ -4.52746979,   4.99695191],
#         [ -4.65976773,   5.12662448],
#         [ -4.78864984,   5.25288179],
#         [ -4.91436984,   5.37597672],
#         [ -5.03715198,   5.49613392],
#         [ -5.15719499,   5.61355193],
#         [ -5.27467625,   5.72840821],
#         [ -5.38975473,   5.84086171],
#         [ -5.50257364,   5.95105564],
#         [ -5.61326249,   6.05911951],
#         [ -5.72193889,   6.16517093],
#         [ -5.82870998,   6.26931704],
#         [ -5.93367375,   6.37165582],
#         [ -6.03692004,   6.47227713],
#         [ -6.1385315 ,   6.57126362],
#         [ -6.23858436,   6.66869149],
#         [ -6.3371491 ,   6.76463124],
#         [ -6.43429103,   6.85914819],
#         [ -6.53007083,   6.95230301],
#         [ -6.62454498,   7.04415219],
#         [ -6.71776618,   7.1347484 ],
#         [ -6.80978366,   7.2241409 ],
#         [ -6.9006435 ,   7.31237576],
#         [ -6.99038894,   7.39949621],
#         [ -7.07906056,   7.48554286],
#         [ -7.16669657,   7.57055388],
#         [ -7.25333294,   7.65456527],
#         [ -7.33900361,   7.73761096],
#         [ -7.42374066,   7.81972302],
#         [ -7.5075744 ,   7.90093179],
#         [ -7.59053357,   7.98126598],
#         [ -7.67264539,   8.06075282],
#         [ -7.75393571,   8.13941816],
#         [ -7.83442909,   8.21728655],
#         [ -7.91414889,   8.29438137],
#         [ -7.99311735,   8.37072485],
#         [ -8.07135566,   8.44633817],
#         [ -8.14888403,   8.52124157],
#         [ -8.22572178,   8.59545433],
#         [ -8.30188733,   8.6689949 ],
#         [ -8.37739833,   8.74188092],
#         [ -8.45227164,   8.81412925],
#         [ -8.52652344,   8.88575607],
#         [ -8.60016922,   8.95677687],
#         [ -8.67322384,   9.0272065 ],
#         [ -8.74570155,   9.09705923],
#         [ -8.81761605,   9.16634875],
#         [ -8.88898052,   9.23508824],
#         [ -8.9598076 ,   9.30329034],
#         [ -9.03010948,   9.37096724],
#         [ -9.09989789,   9.43813066],
#         [ -9.16918412,   9.50479191],
#         [ -9.23797906,   9.57096187],
#         [ -9.30629321,   9.63665104],
#         [ -9.37413671,   9.70186955],
#         [ -9.44151933,   9.76662719],
#         [ -9.50845052,   9.83093341],
#         [ -9.57493942,   9.89479732],
#         [ -9.64099485,   9.95822777],
#         [ -9.70662533,  10.02123327],
#         [ -9.77183914,  10.0838221 ],
#         [ -9.83664426,  10.14600224],
#         [ -9.90104844,  10.20778144],
#         [ -9.96505919,  10.2691672 ],
#         [-10.02868376,  10.33016679],
#         [-10.0919292 ,  10.39078725],
#         [-10.15480237,  10.45103544],
#         [-10.21730988,  10.51091797],
#         [-10.27945818,  10.57044129],
#         [-10.34125352,  10.62961164],
#         [-10.40270198,  10.68843512],
#         [-10.46380944,  10.7469176 ],
#         [-10.52458166,  10.80506484],
#         [-10.58502421,  10.8628824 ],
#         [-10.6451425 ,  10.92037572],
#         [-10.70494182,  10.97755006],
#         [-10.76442731,  11.03441056],
#         [-10.82360395,  11.09096222],
#         [-10.88247662,  11.14720991],
#         [-10.94105006,  11.20315836],
#         [-10.99932888,  11.25881221],
#         [-11.05731759,  11.31417594],
#         [-11.11502058,  11.36925394],
#         [-11.17244212,  11.4240505 ],
#         [-11.22958639,  11.47856979],
#         [-11.28645745,  11.53281587],
#         [-11.34305928,  11.58679272],
#         [-11.39939576,  11.64050422],
#         [-11.45547067,  11.69395414],
#         [-11.5112877 ,  11.74714619],
#         [-11.56685047,  11.80008398],
#         [-11.62216249,  11.85277102],
#         [-11.67722722,  11.90521077],
#         [-11.73204802,  11.95740658],
#         [-11.78662818,  12.00936176],
#         [-11.84097092,  12.06107952],
#         [-11.89507939,  12.11256301],
#         [-11.94895666,  12.1638153 ],
#         [-12.00260575,  12.21483941],
#         [-12.0560296 ,  12.26563827],
#         [-12.10923109,  12.31621478],
#         [-12.16221305,  12.36657176],
#         [-12.21497823,  12.41671196],
#         [-12.26752936,  12.46663811]]))
